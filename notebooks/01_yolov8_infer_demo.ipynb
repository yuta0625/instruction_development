# %%
from pathlib import Path
import os, sys
project_root = Path("/Users/ohya/instruction_development")
os.chdir(project_root)
sys.path.append(str(project_root))
print("Current dir:", Path.cwd())
# Out:
# Current dir: /Users/ohya/instruction_development

# %%
from src.infer_yolov8 import run_inference
cfg_path = "configs/yolov8_origin_demo.yaml"
results = run_inference(cfg_path, step=100)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 640x640 2 persons, 1 cell phone, 63.5ms
# 1: 640x640 1 person, 1 chair, 1 potted plant, 1 vase, 63.5ms
# 2: 640x640 3 persons, 3 cups, 1 orange, 1 cake, 2 chairs, 1 dining table, 63.5ms
# 3: 640x640 1 person, 63.5ms
# 4: 640x640 2 persons, 63.5ms
# 5: 640x640 7 persons, 1 chair, 63.5ms
# 6: 640x640 10 persons, 1 cup, 2 cell phones, 63.5ms
# 7: 640x640 1 person, 63.5ms
# 8: 640x640 4 persons, 63.5ms
# 9: 640x640 1 person, 63.5ms
# ...
